# %%
# GeoSpatial Data Science
import geopandas as gpd
import contextily

# Data Visualization
import seaborn as sns
import matplotlib.pyplot as plt 
import matplotlib.ticker as ticker
# %matplotlib inline
#import geoplot # like seaborn for geospatial
#import geoplot.crs as gcrs

# Network Data Science 
import networkx as nx

# %%
# Set filepath (fix path relative to yours)
italy_regions = "/Users/pietromonticone/Downloads/Limiti01012020/Reg01012020/Reg01012020_WGS84.shp"
italy_provinces = "/Users/pietromonticone/Downloads/Limiti01012020/ProvCM01012020/ProvCM01012020_WGS84.shp"
italy_municipalities = "/Users/pietromonticone/Downloads/Limiti01012020/Com01012020/Com01012020_WGS84.shp"
italy_macroregions = "/Users/pietromonticone/Downloads/Limiti01012020/RipGeo01012020/RipGeo01012020_WGS84.shp"

# Read file using gpd.read_file()
regions = gpd.read_file(italy_regions)
provinces = gpd.read_file(italy_provinces)
municipalities = gpd.read_file(italy_municipalities)
macro_regions = gpd.read_file(italy_macroregions)

# %%
#regions.head()
#provinces.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-31-46cbeae8f450> in <module>
#       1 #regions.head()
# ...

# %%
regions.plot(figsize=(10, 10)).set_axis_off()

# %%
provinces.plot(figsize=(10, 10)).set_axis_off()

# %%
municipalities.plot(figsize=(10, 10)).set_axis_off()

# %%
macro_regions.plot(figsize=(10, 10)).set_axis_off()

# %%
nx.read_shp("/Users/pietromonticone/Downloads/Limiti01012020/Reg01012020/Reg01012020_WGS84.shp")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/networkx/readwrite/nx_shp.py in read_shp(path, simplify, geom_attrs, strict)
#      85     try:
# ---> 86         from osgeo import ogr
#      87     except ImportError:
#
# ModuleNotFoundError: No module named 'osgeo'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# <ipython-input-22-6ba1141281b9> in <module>
# ----> 1 nx.read_shp("/Users/pietromonticone/Downloads/Limiti01012020/Reg01012020/Reg01012020_WGS84.shp")
#       2
#
# ~/opt/anaconda3/lib/python3.7/site-packages/networkx/readwrite/nx_shp.py in read_shp(path, simplify, geom_attrs, strict)
#      86         from osgeo import ogr
#      87     except ImportError:
# ...
