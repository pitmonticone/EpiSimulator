# %% [markdown]
# # Household

# %% [markdown]
# ## Modules

# %%
# Data Wrangling
import numpy as np
import pandas as pd

# %% [markdown]
# ## Age-bracket distribution

# %%
age_population_data=pd.read_csv("/Users/Pit/GitHub/DigitalEpidemiologyProject/Data/CSV/2020/Population/AgeStratifiedProvincialPopulation.csv")
age_brackets=pd.DataFrame(["0_4","5_9","10_14","15_19","20_24","25_29","30_34","35_39","40_44","45_49","50_54","55_59","60_64","65_69","70_74","75_100"])
age_population_data["age_bracket"]=age_brackets

# %%
age_population_data["age_bracket"]=age_brackets

# %%
prov_age_population_data=pd.concat([age_brackets,age_population_data["1"]],axis=1).rename(columns={0:'age_bracket','1':'percent'})
prov_age_population_data["percent"]= prov_age_population_data["percent"] / sum(prov_age_population_data["percent"])
prov_age_population_data.to_csv("/Users/Pit/GitHub/DigitalEpidemiologyProject/Data/CSV/2020/Population/Household/AgeBracketDistribution_"+i+".csv", index=False)

# %%
for prov in range(1,108):
    prov_data=pd.concat([age_brackets,age_population_data[str(prov)]],axis=1).rename(columns={0:'age_bracket',str(prov):'percent'})
    prov_data["percent"]= prov_data["percent"] / sum(prov_data["percent"])
    prov_data.to_csv("/Users/Pit/GitHub/DigitalEpidemiologyProject/Data/CSV/2020/Population/Household/AgeBracketDistributions/"+str(prov)+".csv", index=False)

# %% [markdown]
# ## Age distribution of the reference person for each household size

# %%
pd.read_csv("/Users/Pit/GitHub/DigitalEpidemiologyProject/Data/CSV/2020/Population/Household/FamilySize.csv")
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3145: DtypeWarning: Columns (5,7) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#        ITTER107   Territorio  \
# 0         ITC12     Vercelli
# 1         ITC15       Novara
# 2         ITC15       Novara
# 3         ITC17         Asti
# 4         ITC18  Alessandria
# ...         ...          ...
# 309867        r         data
# 309868        s     estimate
# 309869        t          for
# 309870        u           or
# 309871        y          not
#
#                                                 Tipo dato  \
# 0       popolazione residente in famiglia (valori asso...
# 1       popolazione residente in famiglia (valori asso...
# 2       popolazione residente in famiglia (valori asso...
# 3       popolazione residente in famiglia (valori asso...
# 4       popolazione residente in famiglia (valori asso...
# ...                                                   ...
# 309867                                                NaN
# 309868                                                NaN
# 309869                                                NaN
# 309870                                               (see
# 309871                                          according
#
#        Tipologia della famiglia  Posizione nella famiglia  SEXISTAT1_A  \
# 0                      famiglie  in famiglie unipersonali            2
# 1                      famiglie  in famiglie unipersonali            1
# 2                      famiglie  in famiglie unipersonali            9
# 3                      famiglie  in famiglie unipersonali            2
# 4                      famiglie  in famiglie unipersonali            1
# ...                         ...                       ...          ...
# 309867                      NaN                       NaN          NaN
# 309868                      NaN                       NaN          NaN
# 309869                       da                    titolo           di
# 309870                     dato                   incerto      (vedasi
# 309871                     2011                       non  ricostruito
#
#           Sesso    SEXISTAT1   Classe di et�  \
# 0       femmine            9  fino a 24 anni
# 1        maschi            9  fino a 24 anni
# 2        totale            9  fino a 24 anni
# 3       femmine            9  fino a 24 anni
# 4        maschi            9  fino a 24 anni
# ...         ...          ...             ...
# 309867      NaN          NaN             NaN
# 309868      NaN          NaN             NaN
# 309869      NaN          NaN             NaN
# 309870       di     dataset)             NaN
# 309871     alla  popolazione             NaN
#
#        Classe di et� della persona di riferimento della famiglia  \
# 0                                                  totale
# 1                                                  totale
# 2                                                  totale
# 3                                                  totale
# 4                                                  totale
# ...                                                   ...
# 309867                                                NaN
# 309868                                                NaN
# 309869                                                NaN
# 309870                                                NaN
# 309871                                                NaN
#
#        Stato civile della persona di riferimento della famiglia NUMEROSITA  \
# 0                                                  totale              TOT
# 1                                                  totale              TOT
# 2                                                  totale              TOT
# 3                                                  totale              TOT
# 4                                                  totale              TOT
# ...                                                   ...              ...
# 309867                                                NaN              NaN
# 309868                                                NaN              NaN
# 309869                                                NaN              NaN
# 309870                                                NaN              NaN
# 309871                                                NaN              NaN
#
#        Numero di componenti Condizione abitativa (in/non in coabitazione)  \
# 0                    totale                               in coabitazione
# 1                    totale                               in coabitazione
# 2                    totale                               in coabitazione
# 3                    totale                               in coabitazione
# 4                    totale                               in coabitazione
# ...                     ...                                           ...
# 309867                  NaN                                           NaN
# 309868                  NaN                                           NaN
# 309869                  NaN                                           NaN
# 309870                  NaN                                           NaN
# 309871                  NaN                                           NaN
#
#        Situazione abitativa della famiglia Titolo di godimento  \
# 0                            tutte le voci       tutte le voci
# 1                            tutte le voci       tutte le voci
# 2                            tutte le voci       tutte le voci
# 3                            tutte le voci       tutte le voci
# 4                            tutte le voci       tutte le voci
# ...                                    ...                 ...
# 309867                                 NaN                 NaN
# 309868                                 NaN                 NaN
# 309869                                 NaN                 NaN
# 309870                                 NaN                 NaN
# 309871                                 NaN                 NaN
#
#         Anno di Censimento  Value
# 0                   2011.0   11.0
# 1                   2011.0   30.0
# 2                   2011.0   56.0
# 3                   2011.0   18.0
# 4                   2011.0   20.0
# ...                    ...    ...
# 309867                 NaN    NaN
# 309868                 NaN    NaN
# 309869                 NaN    NaN
# 309870                 NaN    NaN
# 309871                 NaN    NaN
#
# [309872 rows x 18 columns]

# %% [markdown]
# ## Household Size

# %%
household_sizes=pd.read_csv("/Users/Pit/GitHub/DigitalEpidemiologyProject/Data/CSV/2020/Population/HouseholdSizes.csv")
household_sizes_2019=household_sizes[household_sizes.TIME ==2019]
household_sizes_2019=household_sizes_2019.drop(columns=["TIME","Flag Codes", "Flags", "Select time", "NUMEROSITA", "MISURA_AVQ"])
household_sizes_2019=household_sizes_2019[household_sizes_2019["Measure"] =="thousands value"]
household_sizes_2019["Value"]=[int(size) for size in household_sizes_2019["Value"]]
household_sizes_2019=household_sizes_2019.sort_values(by=["Number of household members"])

# %%
household_sizes_2019
# Out:
#    TIPO_DATO_AVQ                    Data type          Measure  \
# 54     HOUSEHOLD  household - biennal average  thousands value
# 34     HOUSEHOLD  household - biennal average  thousands value
# 9      HOUSEHOLD  household - biennal average  thousands value
# 39     HOUSEHOLD  household - biennal average  thousands value
# 19     HOUSEHOLD  household - biennal average  thousands value
# 59     HOUSEHOLD  household - biennal average  thousands value
# 24     HOUSEHOLD  household - biennal average  thousands value
#
#    Number of household members  Value
# 54                           1   8562
# 34                           2   6967
# 9                            3   4954
# 39                           4   3872
# 19                           5   1023
# 59                  6 and over    337
# 24                       total  25715

# %% [markdown]
# ## National-Level Household Types

# %%
household_types_national=pd.read_csv("/Users/Pit/GitHub/DigitalEpidemiologyProject/Data/CSV/2020/Population/HouseholdTypes.csv")
household_types_national_2019=household_types_national[household_types_national.TIME ==2019]
household_types_national_2019=household_types_national_2019.drop(columns=["TIPO_DATO_AVQ","TIME","Flag Codes", "Flags", "Select time", "MISURA_AVQ"])
household_types_national_2019=household_types_national_2019[household_types_national_2019["Measure"] =="thousands value"]
household_types_national_2019["Value"]=[int(t) for t in household_types_national_2019["Value"]]
household_types_national_2019=household_types_national_2019.sort_values(by=["Value"])

# %%
household_types_national_2019
# Out:
#                                       Data type          Measure  Value
# 9                      one parent with children  thousands value    220
# 54                     couples without children  thousands value    261
# 128                       couples with children  thousands value    382
# 64          households with two or more nucleus  thousands value    396
# 14                 a nucleus with other persons  thousands value    863
# 138  reconstituted households - biennal average  thousands value   1297
# 84          unmarried couples - biennal average  thousands value   1371
# 103                    one parent with children  thousands value   2397
# 4                      couples without children  thousands value   4791
# 39                        couples with children  thousands value   8114
# 133                              single persons  thousands value   8562
# 74                 households without a nucleus  thousands value   9154
# 108             a nucleus without other persons  thousands value  15303
# 29                    households with a nucleus  thousands value  16165

# %% [markdown]
# ## Regional-Level Household Types

# %%
regions=np.array(pd.read_csv("/Users/Pit/GitHub/DigitalEpidemiologyProject/Data/CSV/2020/Population/RegionalDemographics.csv").Regioni)
useless=["Italy", "Nord-est", "Nord-ovest", "Nord", "Centro (I)", "Sud", "until 2,000 inhab.", "10,001 - 50,000 inhab.", "metropolitan area - centre", "50,001 inhab. and over", "2,001 - 10,000 inhab.", "metropolitan area - suburbs", "50,001 inhab. and over", "Isole"]

# %%
conditions=("Italy" or "Nord-est" or "Nord-ovest" or "Nord" or "Centro (I)"or "Sud"or "until 2,000 inhab."or "10,001 - 50,000 inhab."or "metropolitan area - centre" or "50,001 inhab. and over"or "2,001 - 10,000 inhab."or "metropolitan area - suburbs"or "50,001 inhab. and over"or "Isole")

# %%
household_types_regional=pd.read_csv("/Users/Pit/GitHub/DigitalEpidemiologyProject/Data/CSV/2020/Population/HouseholdTypesRegional.csv")
household_types_regional_2019=household_types_regional[household_types_regional.TIME ==2019]
household_types_regional_2019=household_types_regional_2019.drop(columns=["ITTER107","TIPO_DATO_AVQ","TIME","Flag Codes", "Flags", "Select time", "MISURA_AVQ"])
household_types_regional_2019=household_types_regional_2019[household_types_regional_2019["Measure"] =="thousands value"]
household_types_regional_2019["Value"]=[int(t) for t in household_types_regional_2019["Value"]]
household_types_regional_2019=household_types_regional_2019[household_types_regional_2019["Data type"]!=("female" or "male")]
household_types_regional_2019=household_types_regional_2019.sort_values(by=["Data type", "Territory"])

# %%
household_types_regional_2019
# Out:
#                            Territory                            Data type  \
# 815           10,001 - 50,000 inhab.                couples with children
# 1311           2,001 - 10,000 inhab.                couples with children
# 611           50,001 inhab. and over                couples with children
# 1329                         Abruzzo                couples with children
# 901                       Basilicata                couples with children
# ...                              ...                                  ...
# 761   Valle d'Aosta / Vallée d'Aoste  unmarried children aged 18-30 years
# 583                           Veneto  unmarried children aged 18-30 years
# 673       metropolitan area - centre  unmarried children aged 18-30 years
# 547      metropolitan area - suburbs  unmarried children aged 18-30 years
# 47                until 2,000 inhab.  unmarried children aged 18-30 years
#
#               Measure  Value
# 815   thousands value   2368
# 1311  thousands value   2053
# 611   thousands value   1424
# 1329  thousands value    191
# 901   thousands value     87
# ...               ...    ...
# 761   thousands value      9
# 583   thousands value    464
# 673   thousands value    848
# 547   thousands value    875
# 47    thousands value    293
#
# [324 rows x 4 columns]
