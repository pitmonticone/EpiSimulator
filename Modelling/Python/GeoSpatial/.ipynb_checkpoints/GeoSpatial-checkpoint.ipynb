# %% [markdown]
# # Geo-spatial Graph Modelling

# %% [markdown]
# ## Modules

# %%
# Network Data Science 
import networkx as nx

# Data Wrangling
import numpy as np

# Network Data Analysis 
import networkx as nx
import geonetworkx as gnx

# Data Visualization
import seaborn as sns
import matplotlib.pyplot as plt 
import matplotlib.ticker as ticker
# %pylab inline

# Geo-Spatial Data Analysis
import geopandas as gpd
import pandas as pd
from shapely.geometry import Point

# Other Utilities
from operator import itemgetter
from collections import defaultdict

# Custom Modules
import digital_epidemiology as depi

# Reload Custom Modules
from importlib import reload
depi = reload(depi)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## Data Collection

# %%
# Set geodata file path
regions = "/Users/pietromonticone/github/DigitalEpidemiologyProject/Data/Shape/Reg01012020/Reg01012020_WGS84.shp"
provinces = "/Users/pietromonticone/github/DigitalEpidemiologyProject/Data/Shape/ProvCM01012020/ProvCM01012020_WGS84.shp"
macro_regions = "/Users/pietromonticone/github/DigitalEpidemiologyProject/Data/Shape/RipGeo01012020/RipGeo01012020_WGS84.shp"
municipalities = "/Users/pietromonticone/github/DigitalEpidemiologyProject/Data/Shape/Com01012020/Com01012020_WGS84.shp"

# Set demodata file path
regional_demographics = "/Users/pietromonticone/github/DigitalEpidemiologyProject/Data/CSV/RegionalDemographics.csv"
provincial_demographics = "/Users/pietromonticone/github/DigitalEpidemiologyProject/Data/CSV/ProvincialDemographics.csv"
municipal_demographics = "/Users/pietromonticone/github/DigitalEpidemiologyProject/Data/CSV/MunicipalDemographics.csv"

#macroregional_data = gpd.read_file(italy_macroregions)
#macroregional_data.plot(figsize=(10, 10)).set_axis_off()

# %% [markdown]
# ## Regional Level

# %% [markdown]
# ### Data Manipulation

# %%
# Store data
regional_data = gpd.read_file(regions)
regional_demo_data = pd.read_csv(regional_demographics)

# Fill column of neighbors 
depi.expand(data=regional_data, level="regional", demo = regional_demo_data)
    
# Visualize GeoDataFrame
regional_data.plot(figsize=(10, 10)).set_axis_off()

# %% [markdown]
# ### Graph Data Manipulation

# %%
# Build the regional undirected graph
regional_graph = depi.build_graph(data = regional_data,
                                  level = "regional",
                                  graph = nx.Graph())

regional_pop_list = [10000*regional_graph.pop[i] for i in list(regional_graph.nodes)] / sum([regional_graph.pop[i] for i in list(regional_graph.nodes)])

# %% [markdown]
# ### Graph Data Visualization

# %%
# Showcase connectivity
print("CONNECTIVITY:\n•",regional_graph.number_of_nodes(),"nodes;\n•",regional_graph.number_of_edges(),"edges.")

# Visualize graph 
fig=plt.figure(figsize=(15,8))
nx.draw_networkx_nodes(regional_graph, pos=regional_graph.pos,node_size=regional_pop_list)
nx.draw_networkx_edges(regional_graph, pos=regional_graph.pos, alpha=0.3) 
nx.draw_networkx_labels(regional_graph, pos=regional_graph.pos)
plt.axis('off')
plt.show()
# Out:
# CONNECTIVITY:
# • 20 nodes;
# • 31 edges.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-cd0c38d4d202> in <module>
#       4 # Visualize graph
#       5 fig=plt.figure(figsize=(15,8))
# ----> 6 nx.draw_networkx_nodes(regional_graph, pos=regional_graph.pos,node_size=regional_graph.pop)
#       7 nx.draw_networkx_edges(regional_graph, pos=regional_graph.pos)
#       8 nx.draw_networkx_labels(regional_graph, pos=regional_graph.pos)
#
# AttributeError: 'Graph' object has no attribute 'pop'

# %% [markdown]
# ### Graph Data Storage

# %%
# Store graphml file 
#nx.write_graphml(regional_graph, "RegionalGraph.graphml")
#nx.write_edgelist(regional_graph, "RegionalGraph.csv", delimiter=',', data=False)

# %% [markdown]
# ## Provincial Level

# %% [markdown]
# ### Data Manipulation

# %%
# Store data
provincial_data = gpd.read_file(provinces)
provincial_demo_data = pd.read_csv(provincial_demographics)

# Fill column of neighbors 
depi.expand(data=provincial_data, level="provincial", demo = provincial_demo_data)
    
# Visualize GeoDataFrame
provincial_data.plot(figsize=(10, 10)).set_axis_off()

# %% [markdown]
# ### Graph Data Manipulation

# %%
# Build the regional undirected graph
provincial_graph = depi.build_graph(data = provincial_data,
                                  level = "provincial",
                                  graph = nx.Graph())

provincial_pop_list = [10000*provincial_graph.pop[i] for i in list(provincial_graph.nodes)] / sum([provincial_graph.pop[i] for i in list(provincial_graph.nodes)])

# %% [markdown]
# ### Graph Data Visualization

# %%
# Showcase connectivity
print("CONNECTIVITY:\n•",provincial_graph.number_of_nodes(),"nodes;\n•",provincial_graph.number_of_edges(),"edges.")

# Visualize Graph
fig=plt.figure(figsize=(15,8))
nx.draw_networkx_nodes(provincial_graph, pos=provincial_graph.pos,node_size=provincial_pop_list)
nx.draw_networkx_edges(provincial_graph,pos=provincial_graph.pos, alpha = 0.5)
#nx.draw_networkx_labels(H, pos=H.pos)
plt.axis('off')
plt.show()
# Out:
# CONNECTIVITY:
# • 107 nodes;
# • 238 edges.

# %% [markdown]
# ### Graph Data Storage

# %%
# Store graphml file 
#nx.write_graphml(provincial_graph, "./ProvincialGraph.graphml")
#nx.write_edgelist(provincial_graph, "./ProvincialGraph.csv", delimiter=',', data=False)

# %% [markdown]
# ## Municipal Level

# %% [markdown]
# ### Data Manipulation

# %%
# Store data
municipal_data = gpd.read_file(municipalities)
municipal_demo_data = pd.read_csv(municipal_demographics)

# Fill column of neighbors 
depi.expand(data=municipal_data, level="municipal", demo = municipal_demo_data)
    
# Visualize GeoDataFrame
municipal_data.plot(figsize=(10, 10)).set_axis_off()

# %% [markdown]
# ### Graph Data Manipulation

# %%
# Build the regional undirected graph
municipal_graph = depi.build_graph(data = municipal_data,
                                  level = "municipal",
                                  graph = nx.Graph())

municipal_pop_list = [10000*municipal_graph.pop[i] for i in list(municipal_graph.nodes)] / sum([municipal_graph.pop[i] for i in list(municipal_graph.nodes)])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-c7a481187321> in <module>
#       1 # Build the regional undirected graph
# ----> 2 municipal_graph = depi.build_graph(data = municipal_data,
#       3                                   level = "municipal",
#       4                                   graph = nx.Graph())
#
# ~/github/DigitalEpidemiologyProject/Modelling/Python/GeoSpatial/digital_epidemiology.py in build_graph(data, level, graph)
#     149             graph.remove_node('')
#     150         # Add name
# --> 151         graph.name = "Graph of Italian Municipalities"
#     152         # Add metadata
#     153         graph.pos = dict.fromkeys(municipal_list)    # position
#
# /opt/anaconda3/lib/python3.8/site-packages/geopandas/base.py in centroid(self)
#     236         """Returns a ``GeoSeries`` of points representing the centroid of each
#     237         geometry."""
# --> 238         return _delegate_property("centroid", self)
#     239
#     240     @property
#
# /opt/anaconda3/lib/python3.8/site-packages/geopandas/base.py in _delegate_property(op, this)
#      72     # type: (str, GeoSeries) -> GeoSeries/Series
#      73     a_this = GeometryArray(this.geometry.values)
# ---> 74     data = getattr(a_this, op)
#      75     if isinstance(data, GeometryArray):
#      76         from .geoseries import GeoSeries
#
# /opt/anaconda3/lib/python3.8/site-packages/geopandas/array.py in centroid(self)
#     445     def centroid(self):
#     446         self.check_geographic_crs(stacklevel=5)
# --> 447         return GeometryArray(vectorized.centroid(self.data), crs=self.crs)
#     448
#     449     @property
#
# /opt/anaconda3/lib/python3.8/site-packages/geopandas/_vectorized.py in centroid(data)
#     555         return pygeos.centroid(data)
#     556     else:
# --> 557         return _unary_geo("centroid", data)
#     558
#     559
#
# /opt/anaconda3/lib/python3.8/site-packages/geopandas/_vectorized.py in _unary_geo(op, left, *args, **kwargs)
#     540     # ensure 1D output, see note above
#     541     data = np.empty(len(left), dtype=object)
# --> 542     data[:] = [getattr(geom, op, None) for geom in left]
#     543     return data
#     544
#
# /opt/anaconda3/lib/python3.8/site-packages/geopandas/_vectorized.py in <listcomp>(.0)
#     540     # ensure 1D output, see note above
#     541     data = np.empty(len(left), dtype=object)
# --> 542     data[:] = [getattr(geom, op, None) for geom in left]
#     543     return data
#     544
#
# /opt/anaconda3/lib/python3.8/site-packages/shapely/geometry/base.py in centroid(self)
#     475     def centroid(self):
#     476         """Returns the geometric center of the object"""
# --> 477         return geom_factory(self.impl['centroid'](self))
#     478
#     479     @delegated
#
# /opt/anaconda3/lib/python3.8/site-packages/shapely/topology.py in __call__(self, this, *args)
#      76     def __call__(self, this, *args):
#      77         self._validate(this)
# ---> 78         return self.fn(this._geom, *args)
#
# KeyboardInterrupt:

# %%
nx.get_node_attributes(municipal_graph, 'population')

# %% [markdown]
# ### Graph Data Visualization

# %%
# Showcase connectivity
print("CONNECTIVITY:\n•",municipal_graph.number_of_nodes(),"nodes;\n•",municipal_graph.number_of_edges(),"edges.")

# Visualize graph 
fig=plt.figure(figsize=(15,8))
#nx.draw_networkx_nodes(municipal_graph, pos=municipal_graph.pos,node_size=0.4)
nx.draw_networkx_nodes(municipal_graph, pos=municipal_graph.pos,node_size=municipal_graph.pop)
nx.draw_networkx_edges(municipal_graph, pos=municipal_graph.pos, alpha = 0.19) 
#nx.draw_networkx_labels(K, pos=K.pos)
plt.axis('off')
plt.show()

# %% [markdown]
# ### Graph Data Storage

# %%
# Store file 
nx.write_graphml(municipal_graph, "./MunicipalGraph.graphml")
nx.write_edgelist(municipal_graph, "./MunicipalGraph.csv", delimiter=',', data=False)

# %% [markdown]
# ### Multiplex Graph Visualization
