# %% [markdown]
# # SIR Model using `DifferentialEquations`
#
# $$ \dot{S} = - \beta S I $$
# $$ \dot{I} = \beta S I - \gamma I $$
# $$ \dot{R} = \gamma I $$
#
# ### Packages

# %%
# Numerical Computation
using DifferentialEquations

# Data Visualization
using Plots
using PlotThemes

# %% [markdown]
# ### Flow

# %%
Φ = @ode_def SIRModel begin
    dS = -β*S*I
    dI = β*S*I-γ*I
    dR = γ*I
    end β γ

### ALternative
#function sir_ode2(du,u,p,t)
#    S,I,R = u
#    b,g = p
#    du[1] = -b*S*I
#    du[2] = b*S*I-g*I
#    du[3] = g*I
#end
# Out:
# (::SIRModel{var"###ParameterizedDiffEqFunction#272",var"###ParameterizedTGradFunction#273",var"###ParameterizedJacobianFunction#274",Nothing,Nothing,ModelingToolkit.ODESystem}) (generic function with 1 method)

# %% [markdown]
# ### Parameters

# %%
ℬ = [0.99,0.01,0.0] # Initial condition
𝒯 = (0.0,200.0)     # Time 
𝒫 = [0.1,0.05]      # Model Parameters
# Out:
# 2-element Array{Float64,1}:
#  0.1
#  0.05

# %% [markdown]
# ### Solution

# %%
# Problem Definition
problem = ODEProblem(Φ, ℬ, 𝒯, 𝒫)

# Problem Solution
solution = solve(problem, saveat = 0.1);

# %% [markdown]
# ### Visualization

# %%
# Select Theme
theme(:default)
#theme(:vibrant)
#theme(:dark)
#theme(:ggplot2)
#theme(:juno)
#theme(:lime)

# Plot 
plot(solution,
     title  = "SIR ODE",
     label = ["S" "I" "R"],
     xlabel = "Time", 
     ylabel = "Number",
     legend = :top)
