# %% [markdown]
# # SEIR Model using `DifferentialEquations`
#
# The implementation in this section considers proportions of susceptibles, exposed, infectious individuals in an open population, with no additional mortality associated with infection (such that the population size remains constant and R is not modelled explicitly).
#
# $$ \dot{S} = \mu - \beta S I - \mu S $$
# $$ \dot{E} = \beta S E - (\sigma + \mu) E $$
# $$ \dot{I} = \sigma E - (\gamma + \mu) I $$
# $$ \dot{R} = \gamma I = \mu R $$
#
# ## Packages

# %%
# Numerical Computation
using DifferentialEquations

# Data Visualization
using Plots
using PlotThemes
using PyPlot
# Out:
# ┌ Info: Precompiling PyPlot [d330b81b-6aea-500a-939a-2ce795aea3ee]
# └ @ Base loading.jl:1260
# WARNING: using PyPlot.plot in module Main conflicts with an existing identifier.

# %% [markdown]
# ## Flow

# %%
function Φ!(du,u,p,t)
    S,E,I,R = u
    β,σ,γ,μ = p
    
    du[1] = μ-β*S*I-μ*S
    du[2] = β*S*I-(σ+μ)*E
    du[3] = σ*E - (γ+μ)*I
    du[4] = γ*I
end
# Out:
# Φ! (generic function with 1 method)

# %% [markdown]
# ## Parameters

# %%
𝒫 = [520/365,1/60,1/30,774835/(65640000*365)]      # Model Parameters
ℬ = [0.8,0.1,0.1, 0.0]                             # Initial condition
𝒯 = (0.0,365.0)                                    # Time
# Out:
# (0.0, 365.0)

# %% [markdown]
# ## Solution

# %%
# Problem Definition
problem = ODEProblem(Φ!, ℬ, 𝒯, 𝒫)

# Problem Solution
solution = solve(problem);

# %% [markdown]
# ## Visualization

# %%
# Select Theme
theme(:default)

plot(solution,
     title  = "SEIR Evolution", 
     xlabel = "Time", 
     ylabel = "Fraction", 
     label=["S" "E" "I" "R"],
     lw=2,
     legend = :right)

# %%
# Panel Plot
plot(solution,
     title  = ["Susceptible" "Exposed" "Infected" "Recovered"], 
     xlabel = "Time", 
     ylabel = "Fraction", 
     label=false,
     layout = (2,2),
     lw=2,
     legend = :right)

# %%
# Phase Diagram
plot(solution, plotdensity=1000, 
    vars=(1,2,3),
    lw=2.5,
    label = false,
    #xlabel = "S",
    xlabel = "S", 
    ylabel = "E",
    zlabel = "I")

# %%
# Area Plot
areaplot(solution.t, 
        solution', 
        labels = ["S" "E" "I" "R"], 
        xlabel="Time",
        ylabel="Proportion",
        title = "SEIR Proportions")
